# %% [markdown]
# # Qualidade

# %%
# !pip install pyspark
# !pip install findspark
# Out:
# Requirement already satisfied: pyspark in c:\users\lcampos\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in c:\users\lcampos\anaconda3\lib\site-packages (from pyspark) (0.10.9.3)
# Requirement already satisfied: findspark in c:\users\lcampos\anaconda3\lib\site-packages (2.0.1)

# %%
import findspark
findspark.init()

# %%
# Expressoes regulares comuns
REGEX_ALPHA    = r'[a-zA-Z]+'
REGEX_INTEGER  = r'[0-9]+'
REGEX_FLOAT    = r'[0-9]+\.[0-9]+'
REGEX_ALPHANUM = r'[0-9a-zA-Z]+'
REGEX_EMPTY_STR= r'[\t ]+$'
REGEX_SPECIAL  = r'[!@#$%&*\(\)_]+'
REGEX_NNUMBER  = r'^N[1-9][0-9]{2,3}([ABCDEFGHJKLMNPRSTUVXWYZ]{1,2})'
REGEX_NNUMBER_INVALID = r'(N0.*$)|(.*[IO].*)'
REGEX_TIME_FMT = r'^(([0-1]?[0-9])|(2[0-3]))([0-5][0-9])$'

# %%
# Funcoes auxiiliares
def split_csv(line):
    return tuple(map(lambda x: x.replace('"',''), line.split(",")))

def check_empty_column(col):
    return (F.col(col).isNull() | (F.col(col) == '') | F.col(col).rlike(REGEX_EMPTY_STR))

# %%
import re
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType

# %%
# Criar o contexto do spark
sc = SparkContext()

# Instancia o criador de sessao do spark
spark = (SparkSession.builder
                     .master("local[7]")
                     .appName("Aceleração PySpark - Capgemini"))

# %%
schema_airports = StructType([
    StructField("faa",  StringType(),  True),
    StructField("name", StringType(),  True),
    StructField("lat",  FloatType(),   True),
    StructField("lon",  FloatType(),   True),
    StructField("alt",  IntegerType(), True),
    StructField("tz",   IntegerType(), True),
    StructField("dst",  StringType(),  True)
])


schema_planes = StructType([
    StructField("tailnum",      StringType(),  True),
    StructField("year",         IntegerType(), True),
    StructField("type",         StringType(),  True),
    StructField("manufacturer", StringType(),  True),
    StructField("model",        StringType(),  True),
    StructField("engines",      IntegerType(), True),
    StructField("seats",        IntegerType(), True),
    StructField("speed",        IntegerType(), True),
    StructField("engine",       StringType(),  True)
])


schema_flights = StructType([
    StructField("year",      IntegerType(), True),
    StructField("month",     IntegerType(), True),
    StructField("day",       IntegerType(), True),
    StructField("dep_time",  StringType(),  True),
    StructField("dep_delay", IntegerType(), True),
    StructField("arr_time",  StringType(),  True),
    StructField("arr_delay", IntegerType(), True),
    StructField("carrier",   StringType(),  True),
    StructField("tailnum",   StringType(),  True),
    StructField("flight",    StringType(),  True),
    StructField("origin",    StringType(),  True),
    StructField("dest",      StringType(),  True),
    StructField("air_time",  IntegerType(), True),
    StructField("distance",  IntegerType(), True),
    StructField("hour",      IntegerType(), True),
    StructField("minute",    IntegerType(), True),
])

# %%
df_airports = (spark.getOrCreate().read
                  .format("csv")
                  .option("header", "true")
                  .schema(schema_airports)
                  .load("../data/airports.csv"))

df_planes = (spark.getOrCreate().read
                  .format("csv")
                  .option("header", "true")
                  .schema(schema_planes)
                  .load("../data/planes.csv"))

df_flights = (spark.getOrCreate().read
                  .format("csv")
                  .option("header", "true")
                  .schema(schema_flights)
                  .load("../data/flights.csv"))

# %% [markdown]
# # Airports Dataset

# %% [markdown]
# ### Pergunta 1

# %%
df_airports = df_airports.withColumn('qa_faa', (
        F.when(check_empty_column('faa'), 'M')
         .when(
            (~F.length(F.col('faa')).between(3, 5) |
            (~F.col('faa').rlike(REGEX_ALPHANUM))), 'F')))

df_airports.show(10)

df_airports.groupBy("qa_faa").count().distinct().show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+
# |faa|                name|      lat|        lon| alt| tz|dst|qa_faa|
# +---+--------------------+---------+-----------+----+---+---+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|  null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|  null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|  null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|  null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|  null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|  null|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|  null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|  null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|  null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|  null|
# +---+--------------------+---------+-----------+----+---+---+------+
# only showing top 10 rows
#
# +------+-----+
# |qa_faa|count|
# +------+-----+
# |  null| 1397|
# +------+-----+

# %% [markdown]
# ### Pergunta 2

# %%
df_airports = df_airports.withColumn('qa_name', F.when(F.col('name').isNull(), 'M'))
df_airports.show(5)

df_airports.groupBy("qa_name").count().distinct().show()
df_airports.filter(F.col('qa_name') == "M").show(5,False)
# Out:
# +---+--------------------+---------+---------+----+---+---+------+-------+
# |faa|                name|      lat|      lon| alt| tz|dst|qa_faa|qa_name|
# +---+--------------------+---------+---------+----+---+---+------+-------+
# |04G|   Lansdowne Airport|41.130474|-80.61958|1044| -5|  A|  null|   null|
# |06A|Moton Field Munic...| 32.46057|-85.68003| 264| -5|  A|  null|   null|
# |06C| Schaumburg Regional| 41.98934|-88.10124| 801| -6|  A|  null|   null|
# |06N|     Randall Airport| 41.43191|-74.39156| 523| -5|  A|  null|   null|
# |09J|Jekyll Island Air...|31.074472|-81.42778|  11| -4|  A|  null|   null|
# +---+--------------------+---------+---------+----+---+---+------+-------+
# only showing top 5 rows
#
# +-------+-----+
# |qa_name|count|
# +-------+-----+
# |   null| 1397|
# +-------+-----+
#
# +---+----+---+---+---+---+---+------+-------+
# |faa|name|lat|lon|alt|tz |dst|qa_faa|qa_name|
# +---+----+---+---+---+---+---+------+-------+
# +---+----+---+---+---+---+---+------+-------+

# %% [markdown]
# ### Pergunta 3

# %%
df_airports = df_airports.withColumn("qa_lat",
                   F.when(F.col('lat').isNull(), "M")
                   .when(~F.col('lat').between(-180,180), "I")
                   .when(F.col('lat').rlike('^[a-zA-Z0-9_]*$'), "A"))
df_airports.show()

df_airports.groupBy("qa_lat").count().distinct().show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+
# |faa|                name|      lat|        lon| alt| tz|dst|qa_faa|qa_name|qa_lat|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|  null|   null|  null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|  null|   null|  null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|  null|   null|  null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|  null|   null|  null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|  null|   null|  null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|  null|   null|  null|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|  null|   null|  null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|  null|   null|  null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|  null|   null|  null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|  null|   null|  null|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409| -5|  A|  null|   null|  null|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875| -6|  U|  null|   null|  null|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003| -5|  A|  null|   null|  null|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951| -4|  U|  null|   null|  null|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789| -4|  A|  null|   null|  null|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122| -5|  A|  null|   null|  null|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152| -8|  A|  null|   null|  null|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670| -6|  U|  null|   null|  null|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134| -4|  A|  null|   null|  null|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885| -5|  U|  null|   null|  null|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+
# only showing top 20 rows
#
# +------+-----+
# |qa_lat|count|
# +------+-----+
# |  null| 1397|
# +------+-----+

# %% [markdown]
# ### Pergunta 4

# %%
df_airports = df_airports.withColumn("qa_lon",
                   F.when(F.col('lon').isNull(), "M")
                   .when(~F.col('lon').between(-180,180), "I")
                   .when(F.col('lon').rlike('^[a-zA-Z0-9_]*$'), "A"))
df_airports.show()

df_airports.groupBy("qa_lon").count().distinct().show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+
# |faa|                name|      lat|        lon| alt| tz|dst|qa_faa|qa_name|qa_lat|qa_lon|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|  null|   null|  null|  null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|  null|   null|  null|  null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|  null|   null|  null|  null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|  null|   null|  null|  null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|  null|   null|  null|  null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|  null|   null|  null|  null|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|  null|   null|  null|  null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|  null|   null|  null|  null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|  null|   null|  null|  null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|  null|   null|  null|  null|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409| -5|  A|  null|   null|  null|  null|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875| -6|  U|  null|   null|  null|  null|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003| -5|  A|  null|   null|  null|  null|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951| -4|  U|  null|   null|  null|  null|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789| -4|  A|  null|   null|  null|  null|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122| -5|  A|  null|   null|  null|  null|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152| -8|  A|  null|   null|  null|  null|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670| -6|  U|  null|   null|  null|  null|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134| -4|  A|  null|   null|  null|  null|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885| -5|  U|  null|   null|  null|  null|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+
# only showing top 20 rows
#
# +------+-----+
# |qa_lon|count|
# +------+-----+
# |  null| 1397|
# +------+-----+

# %% [markdown]
# ### Pergunta 5

# %%
df_airports = df_airports.withColumn('qa_alt', (
            F.when(check_empty_column('alt'), 'M')
             .when(~F.col('alt').rlike(REGEX_INTEGER), 'A')             
             .when(F.col('alt') < 0, 'I')))

df_airports.groupBy("qa_alt").count().distinct().show()
df_airports.filter(F.col('alt') < 0).show()
# Out:
# +------+-----+
# |qa_alt|count|
# +------+-----+
# |  null| 1395|
# |     I|    2|
# +------+-----+
#
# +---+-------------+---------+----------+---+---+---+------+-------+------+------+------+
# |faa|         name|      lat|       lon|alt| tz|dst|qa_faa|qa_name|qa_lat|qa_lon|qa_alt|
# +---+-------------+---------+----------+---+---+---+------+-------+------+------+------+
# |IPL|  Imperial Co| 32.83422|-115.57874|-54| -8|  A|  null|   null|  null|  null|     I|
# |NJK|El Centro Naf|32.829224|-115.67167|-42| -8|  A|  null|   null|  null|  null|     I|
# +---+-------------+---------+----------+---+---+---+------+-------+------+------+------+

# %% [markdown]
# ### Pergunta 6

# %%
df_airports = df_airports.withColumn("qa_tz",
                    F.when(F.col('tz').isNull(), "M")
                    .when(~F.col('tz').between(-11,14), "I")
                    .when(~F.col('tz').rlike(REGEX_INTEGER), "A"))
df_airports.show()

df_airports.groupBy("qa_tz").count().distinct().show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+------+-----+
# |faa|                name|      lat|        lon| alt| tz|dst|qa_faa|qa_name|qa_lat|qa_lon|qa_alt|qa_tz|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+------+-----+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|  null|   null|  null|  null|  null| null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|  null|   null|  null|  null|  null| null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|  null|   null|  null|  null|  null| null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|  null|   null|  null|  null|  null| null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|  null|   null|  null|  null|  null| null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|  null|   null|  null|  null|  null| null|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|  null|   null|  null|  null|  null| null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|  null|   null|  null|  null|  null| null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|  null|   null|  null|  null|  null| null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|  null|   null|  null|  null|  null| null|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409| -5|  A|  null|   null|  null|  null|  null| null|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875| -6|  U|  null|   null|  null|  null|  null| null|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003| -5|  A|  null|   null|  null|  null|  null| null|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951| -4|  U|  null|   null|  null|  null|  null| null|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789| -4|  A|  null|   null|  null|  null|  null| null|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122| -5|  A|  null|   null|  null|  null|  null| null|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152| -8|  A|  null|   null|  null|  null|  null| null|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670| -6|  U|  null|   null|  null|  null|  null| null|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134| -4|  A|  null|   null|  null|  null|  null| null|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885| -5|  U|  null|   null|  null|  null|  null| null|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+------+-----+
# only showing top 20 rows
#
# +-----+-----+
# |qa_tz|count|
# +-----+-----+
# | null| 1397|
# +-----+-----+

# %% [markdown]
# ### Pergunta 7

# %%
categorias = ["E", "A", "S", "O", "Z", "N","U"]

df_airports = df_airports.withColumn("qa_dst",
                  F.when(F.col('dst').isNull(), "M")
                  .when(~F.col('dst').isin(categorias), "C")
                  .when(F.col('dst').rlike("^[0-9]*$"), "N"))

df_airports.show()
df_airports.printSchema

df_airports.groupBy("qa_dst").count().distinct().show()
# Out:
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+------+-----+------+
# |faa|                name|      lat|        lon| alt| tz|dst|qa_faa|qa_name|qa_lat|qa_lon|qa_alt|qa_tz|qa_dst|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+------+-----+------+
# |04G|   Lansdowne Airport|41.130474|  -80.61958|1044| -5|  A|  null|   null|  null|  null|  null| null|  null|
# |06A|Moton Field Munic...| 32.46057|  -85.68003| 264| -5|  A|  null|   null|  null|  null|  null| null|  null|
# |06C| Schaumburg Regional| 41.98934|  -88.10124| 801| -6|  A|  null|   null|  null|  null|  null| null|  null|
# |06N|     Randall Airport| 41.43191|  -74.39156| 523| -5|  A|  null|   null|  null|  null|  null| null|  null|
# |09J|Jekyll Island Air...|31.074472|  -81.42778|  11| -4|  A|  null|   null|  null|  null|  null| null|  null|
# |0A9|Elizabethton Muni...|36.371223| -82.173416|1593| -4|  A|  null|   null|  null|  null|  null| null|  null|
# |0G6|Williams County A...|41.467304| -84.506775| 730| -5|  A|  null|   null|  null|  null|  null| null|  null|
# |0G7|Finger Lakes Regi...|42.883564| -76.781235| 492| -5|  A|  null|   null|  null|  null|  null| null|  null|
# |0P2|Shoestring Aviati...|39.794823| -76.647194|1000| -5|  U|  null|   null|  null|  null|  null| null|  null|
# |0S9|Jefferson County ...| 48.05381|-122.810646| 108| -8|  A|  null|   null|  null|  null|  null| null|  null|
# |0W3|Harford County Ai...|39.566837|   -76.2024| 409| -5|  A|  null|   null|  null|  null|  null| null|  null|
# |10C|  Galt Field Airport| 42.40289| -88.375114| 875| -6|  U|  null|   null|  null|  null|  null| null|  null|
# |17G|Port Bucyrus-Craw...|40.781555|  -82.97481|1003| -5|  A|  null|   null|  null|  null|  null| null|  null|
# |19A|Jackson County Ai...|34.175865|   -83.5616| 951| -4|  U|  null|   null|  null|  null|  null| null|  null|
# |1A3|Martin Campbell F...|35.015804|  -84.34683|1789| -4|  A|  null|   null|  null|  null|  null| null|  null|
# |1B9| Mansfield Municipal|42.000134|  -71.19677| 122| -5|  A|  null|   null|  null|  null|  null| null|  null|
# |1C9|Frazier Lake Airpark|54.013332| -124.76833| 152| -8|  A|  null|   null|  null|  null|  null| null|  null|
# |1CS|Clow Internationa...|41.695976| -88.129234| 670| -6|  U|  null|   null|  null|  null|  null| null|  null|
# |1G3|  Kent State Airport| 41.15139|  -81.41511|1134| -4|  A|  null|   null|  null|  null|  null| null|  null|
# |1OH|     Fortman Airport|40.555325|  -84.38662| 885| -5|  U|  null|   null|  null|  null|  null| null|  null|
# +---+--------------------+---------+-----------+----+---+---+------+-------+------+------+------+-----+------+
# only showing top 20 rows
#
# +------+-----+
# |qa_dst|count|
# +------+-----+
# |  null| 1397|
# +------+-----+

# %% [markdown]
# ### Criando Airports parquet

# %%
(df_airports.select("faa","qa_faa","qa_name","qa_lat","qa_lon","qa_alt","qa_tz","qa_dst")
            .repartition(1) # coalesce
            .write.format("parquet")
            .mode('overwrite')
            .option("header", "true")
            .save("airports_qa.parquet"))

# %% [markdown]
# # Planes Dataset

# %% [markdown]
# ### Pergunta 1

# %%
df_planes = (df_planes.withColumn('qa_tailnum',
F.when((F.col('tailnum').isNull()), "M")
.when((F.length(F.col('tailnum')) != 5) & (F.length(F.col('tailnum')) != 6), "S")
.when((F.col('tailnum').rlike("^N([0-9]{1,4})([A-Z]{1,2}$)") == False), "F")
.when((F.col('tailnum').rlike("^N") == False), "FN")
.when((F.col('tailnum').rlike("^[IO0]") == True), "FE"))
)

df_planes.groupBy("qa_tailnum").count().distinct().show()
# Out:
# +----------+-----+
# |qa_tailnum|count|
# +----------+-----+
# |         F|  298|
# |      null| 2330|
# +----------+-----+

# %% [markdown]
# ### Pergunta 2

# %%
df_planes = df_planes.withColumn('qa_year',
                  F.when(F.col('year').isNull(), "M")
                  .when(F.col('year') < 1950, "I")
                  )


df_planes.groupBy("qa_year").count().distinct().show()
# Out:
# +-------+-----+
# |qa_year|count|
# +-------+-----+
# |   null| 2567|
# |      M|   60|
# |      I|    1|
# +-------+-----+

# %% [markdown]
# ### Pergunta 3

# %%
categorias = ["Fixed wing multi engine","Fixed wing single engine","Rotorcraft"]
df_planes = df_planes.withColumn('qa_type',
                  F.when(F.col('type').isNull(), "M")
                  .when(~F.col('type').isin(categorias), "C")
                  )


df_planes.groupBy("qa_type").count().distinct().show()
# Out:
# +-------+-----+
# |qa_type|count|
# +-------+-----+
# |   null| 2628|
# +-------+-----+

# %% [markdown]
# ### Pergunta 4

# %%
manufacturer_list = ["AIRBUS", "BOEING","BOMBARDIER", "CESSNA","EMBRAER","SIKORSKY", "CANADAIR",
"PIPER", "MCDONNELL DOUGLAS", "CIRRUS", "BELL", "KILDALL GARY","LAMBERT RICHARD", "BARKER JACK",
"ROBINSON HELICOPTER", "GULFSTREAM", "MARZ BARRY"]



df_planes = df_planes.withColumn("qa_manufacturer",
F.when(F.col('manufacturer').isNull(), "M")
.when(~F.col('manufacturer').isin(manufacturer_list), "C"))



df_planes.groupBy("qa_manufacturer").count().distinct().orderBy("qa_manufacturer", ascending=True).show()
# Out:
# +---------------+-----+
# |qa_manufacturer|count|
# +---------------+-----+
# |           null| 2007|
# |              C|  621|
# +---------------+-----+

# %% [markdown]
# ### Pergunta 5

# %%
df_planes = df_planes.withColumn('qa_model', (
        F.when(check_empty_column('model'), 'M')
         .when(
             ((F.col('manufacturer').rlike(r'.*AIRBUS.*') & ~F.col('model').startswith('A')) |
              (F.col('manufacturer').rlike(r'.*BOEING.*') & ~F.col('model').startswith('7')) |
              (F.col('manufacturer').rlike(r'.*(BOMBARDIER|CANADAIR).*') & ~F.col('model').startswith('CL')) |
              (F.col('manufacturer').rlike(r'.*MCDONNELL DOUGLAS.*') &  ~(F.col('model').startswith('MD') | F.col('model').startswith('DC')) )), 'F')))


df_planes.groupBy("qa_model").count().distinct().show()
# Out:
# +--------+-----+
# |qa_model|count|
# +--------+-----+
# |       F|   15|
# |    null| 2613|
# +--------+-----+

# %% [markdown]
# ### Pergunta 6

# %%
df_planes = df_planes.withColumn('qa_engines',
                  F.when(F.col('engines').isNull(), "M")
                  .when((~F.col('engines').between(1,4)), "I")
                  .when(~F.col('engines').rlike(REGEX_INTEGER), "A")  
                  )


df_planes.groupBy("qa_engines").count().distinct().show()
df_planes.show()
# Out:
# +----------+-----+
# |qa_engines|count|
# +----------+-----+
# |      null| 2628|
# +----------+-----+
#
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+---------------+--------+----------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_tailnum|qa_year|qa_type|qa_manufacturer|qa_model|qa_engines|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+---------------+--------+----------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         F|   null|   null|           null|    null|      null|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      null|   null|   null|           null|    null|      null|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      null|   null|   null|           null|    null|      null|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         F|   null|   null|           null|    null|      null|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      null|   null|   null|           null|    null|      null|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+---------------+--------+----------+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 7

# %%
df_planes = df_planes.withColumn('qa_seats',
                  F.when(F.col('seats').isNull(), "M")
                  .when(~F.col('seats').between(2,500), "I")
                  .when(~F.col('seats').rlike(REGEX_INTEGER), "A")  
                  )
df_planes.groupBy("qa_seats").count().distinct().show()
# Out:
# +--------+-----+
# |qa_seats|count|
# +--------+-----+
# |    null| 2628|
# +--------+-----+

# %% [markdown]
# ### Pergunta 8

# %%
df_planes = df_planes.withColumn('qa_speed',
                  F.when(F.col('speed').isNull(), "M")
                  .when(~F.col('speed').between(50,150), "I")
                  .when(~F.col('speed').rlike(REGEX_INTEGER), "A")  
                  )


df_planes.groupBy("qa_speed").count().distinct().show()



df_planes.filter(F.col('qa_speed')=="A").show()
# Out:
# +--------+-----+
# |qa_speed|count|
# +--------+-----+
# |    null|    6|
# |       M| 2622|
# +--------+-----+
#
# +-------+----+----+------------+-----+-------+-----+-----+------+----------+-------+-------+---------------+--------+----------+--------+--------+
# |tailnum|year|type|manufacturer|model|engines|seats|speed|engine|qa_tailnum|qa_year|qa_type|qa_manufacturer|qa_model|qa_engines|qa_seats|qa_speed|
# +-------+----+----+------------+-----+-------+-----+-----+------+----------+-------+-------+---------------+--------+----------+--------+--------+
# +-------+----+----+------------+-----+-------+-----+-----+------+----------+-------+-------+---------------+--------+----------+--------+--------+

# %% [markdown]
# ### Pergunta 9

# %%
motor_categories = ["Turbo-fan", "Turbo-jet", "Turbo-prop", "Turbo-shaft", "4 Cycle"]

df_planes = df_planes.withColumn('qa_engine',
                  F.when(F.col('engine').isNull(), "M")
                  .when(~F.col('engine').isin(motor_categories), "C"))



df_planes.groupBy("qa_engine").count().distinct().show()
df_planes.show()
# Out:
# +---------+-----+
# |qa_engine|count|
# +---------+-----+
# |     null| 2618|
# |        C|   10|
# +---------+-----+
#
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+---------------+--------+----------+--------+--------+---------+
# |tailnum|year|                type|    manufacturer|   model|engines|seats|speed|   engine|qa_tailnum|qa_year|qa_type|qa_manufacturer|qa_model|qa_engines|qa_seats|qa_speed|qa_engine|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+---------------+--------+----------+--------+--------+---------+
# | N102UW|1998|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N103US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N104UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N105UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N107US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N108UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N109UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N110UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N111US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N11206|2000|Fixed wing multi ...|          BOEING| 737-824|      2|  149| null|Turbo-fan|         F|   null|   null|           null|    null|      null|    null|       M|     null|
# | N112US|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N113UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N114UW|1999|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N117UW|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N118US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N119US|2000|Fixed wing multi ...|AIRBUS INDUSTRIE|A320-214|      2|  182| null|Turbo-fan|      null|   null|   null|              C|    null|      null|    null|       M|     null|
# | N1200K|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      null|   null|   null|           null|    null|      null|    null|       M|     null|
# | N1201P|1998|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      null|   null|   null|           null|    null|      null|    null|       M|     null|
# | N12114|1995|Fixed wing multi ...|          BOEING| 757-224|      2|  178| null|Turbo-jet|         F|   null|   null|           null|    null|      null|    null|       M|     null|
# | N121DE|1987|Fixed wing multi ...|          BOEING| 767-332|      2|  330| null|Turbo-fan|      null|   null|   null|           null|    null|      null|    null|       M|     null|
# +-------+----+--------------------+----------------+--------+-------+-----+-----+---------+----------+-------+-------+---------------+--------+----------+--------+--------+---------+
# only showing top 20 rows

# %% [markdown]
# ### Criando planes parquet

# %%
planesparq = (df_planes.select("tailnum","qa_tailnum",'qa_year','qa_type','qa_manufacturer','qa_model','qa_engines','qa_seats','qa_speed','qa_engine')
            .repartition(1) # coalesce
            .write.format("parquet")
            .mode('overwrite')
            .option("header", "true")
            .save('planes_qa.parquet'))

# %% [markdown]
# # Flights Dataset

# %% [markdown]
# ### Pergunta 1

# %%
df_flights = df_flights.withColumn("qa_year_month_day",
                  F.when(F.col('year').isNull(), "MY")
                  .when(F.col('month').isNull(),"MM")
                  .when(F.col('day').isNull(), "MD")
                  .when(F.col('year') < 1950, "YM")
                  .when(~F.col('month').between(1,12), "IM")
                  .when(~F.col('day').between(1,31) | ((F.col('month') == 2) & (F.col('day') > 29)), "ID")
                  )



df_flights.groupBy("qa_year_month_day").count().distinct().show()
# Out:
# +-----------------+-----+
# |qa_year_month_day|count|
# +-----------------+-----+
# |             null|10000|
# +-----------------+-----+

# %% [markdown]
# ### Pergunta 2

# %%
df_flights = df_flights.withColumn("qa_hour_minute",
                  F.when(F.col('hour').isNull(), "MH")
                  .when(F.col('minute').isNull(),"MM")
                  .when(~F.col('hour').between(0,24),"IH")
                  .when(~F.col('minute').between(0,59),"IM")
                  ) 


df_flights.groupBy("qa_hour_minute").count().distinct().show()
df_flights.filter(F.col('qa_hour_minute')=="MH").toPandas()
# Out:
# +--------------+-----+
# |qa_hour_minute|count|
# +--------------+-----+
# |          null| 9952|
# |            MH|   48|
# +--------------+-----+
#     year  month  day dep_time  dep_delay arr_time  arr_delay carrier tailnum  \
# 0   2014      3    4       NA        NaN       NA        NaN      UA      NA
# 1   2014      2   12       NA        NaN       NA        NaN      AS  N527AS
# 2   2014      7    1       NA        NaN       NA        NaN      WN  N8323C
# 3   2014      4   30       NA        NaN       NA        NaN      AS  N526AS
# 4   2014      1    3       NA        NaN       NA        NaN      US      NA
# 5   2014      8    7       NA        NaN       NA        NaN      AS  N579AS
# 6   2014      8   11       NA        NaN       NA        NaN      OO  N689CA
# 7   2014      1    2       NA        NaN       NA        NaN      UA      NA
# 8   2014      5   15       NA        NaN       NA        NaN      OO  N917SW
# 9   2014      2    7       NA        NaN       NA        NaN      OO  N594SW
# 10  2014      6    6       NA        NaN       NA        NaN      WN  N645SW
# 11  2014      1    5       NA        NaN       NA        NaN      UA      NA
# 12  2014      1    6       NA        NaN       NA        NaN      UA      NA
# 13  2014      3   30       NA        NaN       NA        NaN      US      NA
# 14  2014      2    9       NA        NaN       NA        NaN      OO  N580SW
# 15  2014      2    9       NA        NaN       NA        NaN      OO  N297SW
# 16  2014      1    1       NA        NaN       NA        NaN      OO  N295SW
# 17  2014      2   17       NA        NaN       NA        NaN      AA  N3LCAA
# 18  2014      1    5       NA        NaN       NA        NaN      UA      NA
# 19  2014      5   26       NA        NaN       NA        NaN      UA      NA
# 20  2014      6   20       NA        NaN       NA        NaN      UA      NA
# 21  2014      8   10       NA        NaN       NA        NaN      OO  N689CA
# 22  2014      2   16       NA        NaN       NA        NaN      UA      NA
# 23  2014     11   13       NA        NaN       NA        NaN      OO  N617QX
# 24  2014      4   25       NA        NaN       NA        NaN      OO  N216AG
# 25  2014      1   28       NA        NaN       NA        NaN      DL  N3744F
# 26  2014      1    6       NA        NaN       NA        NaN      B6  N805JB
# 27  2014      1    4       NA        NaN       NA        NaN      WN  N400WN
# 28  2014      9   24       NA        NaN       NA        NaN      OO  N983CA
# 29  2014      7    3       NA        NaN       NA        NaN      OO  N953SW
# 30  2014      2    9       NA        NaN       NA        NaN      OO  N580SW
# 31  2014     12   16       NA        NaN       NA        NaN      OO  N963SW
# 32  2014      9   26       NA        NaN       NA        NaN      AS  N514AS
# 33  2014      2    4       NA        NaN       NA        NaN      DL  N721TW
# 34  2014      1   18       NA        NaN       NA        NaN      OO  N568SW
# 35  2014      1    5       NA        NaN       NA        NaN      UA      NA
# 36  2014      8   16       NA        NaN       NA        NaN      UA      NA
# 37  2014     10    2       NA        NaN       NA        NaN      WN  N8647A
# 38  2014      1    5       NA        NaN       NA        NaN      UA      NA
# 39  2014      2   16       NA        NaN       NA        NaN      US      NA
# 40  2014      2   27       NA        NaN       NA        NaN      OO  N946SW
# 41  2014      2    9       NA        NaN       NA        NaN      AS  N627AS
# 42  2014      1   30       NA        NaN       NA        NaN      WN  N773SA
# 43  2014      2    8       NA        NaN       NA        NaN      OO  N593ML
# 44  2014      2    4       NA        NaN       NA        NaN      AA  N3DRAA
# 45  2014     10   14       NA        NaN       NA        NaN      AS  N529AS
# 46  2014      2   17       NA        NaN       NA        NaN      WN  N449WN
# 47  2014      8   12       NA        NaN       NA        NaN      OO  N162PQ
#
#    flight origin dest  air_time  distance  hour  minute qa_year_month_day  \
# 0     156    SEA  DEN       NaN      1024   NaN     NaN              None
# 1       2    SEA  DCA       NaN      2329   NaN     NaN              None
# 2    2485    SEA  MDW       NaN      1733   NaN     NaN              None
# 3     566    PDX  LAX       NaN       834   NaN     NaN              None
# 4     553    SEA  PHL       NaN      2378   NaN     NaN              None
# 5     867    SEA  OGG       NaN      2640   NaN     NaN              None
# 6    4528    PDX  SEA       NaN       129   NaN     NaN              None
# 7     212    SEA  EWR       NaN      2402   NaN     NaN              None
# 8    6250    PDX  LAX       NaN       834   NaN     NaN              None
# 9    5553    PDX  SFO       NaN       550   NaN     NaN              None
# 10    956    PDX  OAK       NaN       543   NaN     NaN              None
# 11    758    PDX  IAH       NaN      1825   NaN     NaN              None
# 12   1729    SEA  DEN       NaN      1024   NaN     NaN              None
# 13    500    SEA  PHX       NaN      1107   NaN     NaN              None
# 14   5438    PDX  EUG       NaN       106   NaN     NaN              None
# 15   5342    SEA  PDX       NaN       129   NaN     NaN              None
# 16   5403    PDX  EUG       NaN       106   NaN     NaN              None
# 17   1236    SEA  ORD       NaN      1721   NaN     NaN              None
# 18    995    PDX  SFO       NaN       550   NaN     NaN              None
# 19    690    SEA  ORD       NaN      1721   NaN     NaN              None
# 20   1142    SEA  IAH       NaN      1874   NaN     NaN              None
# 21   4528    PDX  SEA       NaN       129   NaN     NaN              None
# 22   1523    SEA  SFO       NaN       679   NaN     NaN              None
# 23   4825    PDX  SEA       NaN       129   NaN     NaN              None
# 24   3478    PDX  LGB       NaN       846   NaN     NaN              None
# 25   2482    PDX  ATL       NaN      2172   NaN     NaN              None
# 26    598    SEA  BOS       NaN      2496   NaN     NaN              None
# 27   4174    SEA  DEN       NaN      1024   NaN     NaN              None
# 28   5197    PDX  SFO       NaN       550   NaN     NaN              None
# 29   5210    PDX  SFO       NaN       550   NaN     NaN              None
# 30   5433    SEA  PDX       NaN       129   NaN     NaN              None
# 31   5197    PDX  SFO       NaN       550   NaN     NaN              None
# 32    686    PDX  ORD       NaN      1739   NaN     NaN              None
# 33    182    SEA  JFK       NaN      2422   NaN     NaN              None
# 34   5379    PDX  SEA       NaN       129   NaN     NaN              None
# 35   1599    SEA  ORD       NaN      1721   NaN     NaN              None
# 36   1752    SEA  SFO       NaN       679   NaN     NaN              None
# 37    827    SEA  MDW       NaN      1733   NaN     NaN              None
# 38    732    SEA  ORD       NaN      1721   NaN     NaN              None
# 39    614    SEA  PHX       NaN      1107   NaN     NaN              None
# 40   5196    PDX  SFO       NaN       550   NaN     NaN              None
# 41    682    SEA  DEN       NaN      1024   NaN     NaN              None
# 42    387    SEA  MDW       NaN      1733   NaN     NaN              None
# 43   6250    PDX  LAX       NaN       834   NaN     NaN              None
# 44    125    SEA  ORD       NaN      1721   NaN     NaN              None
# 45    413    PDX  SEA       NaN       129   NaN     NaN              None
# 46   1900    SEA  MDW       NaN      1733   NaN     NaN              None
# 47   4489    SEA  PDX       NaN       129   NaN     NaN              None
#
#    qa_hour_minute
# 0              MH
# 1              MH
# 2              MH
# 3              MH
# 4              MH
# 5              MH
# 6              MH
# 7              MH
# 8              MH
# 9              MH
# 10             MH
# 11             MH
# 12             MH
# 13             MH
# 14             MH
# 15             MH
# 16             MH
# 17             MH
# 18             MH
# 19             MH
# 20             MH
# 21             MH
# 22             MH
# 23             MH
# 24             MH
# 25             MH
# 26             MH
# 27             MH
# 28             MH
# 29             MH
# 30             MH
# 31             MH
# 32             MH
# 33             MH
# 34             MH
# 35             MH
# 36             MH
# 37             MH
# 38             MH
# 39             MH
# 40             MH
# 41             MH
# 42             MH
# 43             MH
# 44             MH
# 45             MH
# 46             MH
# 47             MH

# %% [markdown]
# ### Pergunta 3

# %%
df_flights = df_flights.withColumn("qa_dep_arr",
                  F.when((F.col('dep_time').isNull())  | (F.col('dep_time') == "NA") , "MD")
                  .when(F.col('arr_time').isNull() | (F.col('arr_time') == "NA"),"MA")
                  .when(~F.col('dep_time').rlike("^([0-9]|1[0-9]|2[0-3])[0-5][0-9]$"), "FD")
                  .when(~F.col('arr_time').rlike("^([0-9]|1[0-9]|2[0-3])[0-5][0-9]$"), "FA")                   
                  )


df_flights.groupBy("qa_dep_arr").count().distinct().show()
# Out:
# +----------+-----+
# |qa_dep_arr|count|
# +----------+-----+
# |      null| 9704|
# |        MD|   48|
# |        FA|  151|
# |        MA|    7|
# |        FD|   90|
# +----------+-----+

# %% [markdown]
# ### Pergunta 4

# %%
df_flights = df_flights.withColumn("qa_dep_arr_delay",
                  F.when(F.col('dep_delay').isNull(), "MD")
                  .when(F.col('arr_delay').isNull(), "MA"))



df_flights.groupBy("qa_dep_arr_delay").count().distinct().show()
# Out:
# +----------------+-----+
# |qa_dep_arr_delay|count|
# +----------------+-----+
# |            null| 9925|
# |              MD|   48|
# |              MA|   27|
# +----------------+-----+

# %% [markdown]
# ### Pergunta 5

# %%
df_flights = df_flights.withColumn("qa_carrier",
                  F.when(F.col('carrier').isNull(), "M")
                  .when(~F.col('carrier').rlike("^[a-zA-Z0-9_]{2}$"), "F")
                  )


df_flights.groupBy("qa_carrier").count().distinct().show()
# Out:
# +----------+-----+
# |qa_carrier|count|
# +----------+-----+
# |      null|10000|
# +----------+-----+

# %% [markdown]
# ### Pergunta 6

# %%
df_flights = (df_flights.withColumn('qa_tailnum',
F.when((F.col('tailnum').isNull()) | (F.col('tailnum') == 'NA') , "M")
.when((F.length(F.col('tailnum')) != 5) & (F.length(F.col('tailnum')) != 6), "S")
.when((F.col('tailnum').rlike("^N") == False), "FN")
.when((F.col('tailnum').rlike("^[IO0]") == True), "FE")
.when((F.col('tailnum').rlike("^N([0-9]{1,4})([A-Z]{1,2}$)") == False), "F"))
)



df_flights.groupBy("qa_tailnum").count().distinct().orderBy("qa_tailnum", ascending=True).show()
# Out:
# +----------+-----+
# |qa_tailnum|count|
# +----------+-----+
# |      null| 8997|
# |         F|  987|
# |        FN|    2|
# |         M|   14|
# +----------+-----+

# %% [markdown]
# ### Pergunta 7

# %%
df_flights = df_flights.withColumn('qa_flight',
                  F.when(F.col('flight').isNull(), "M")
                  .when(~F.col('flight').rlike("^[0-9]{4}$"), "F")
                  )


df_flights.groupBy("qa_flight").count().distinct().show()

df_flights.select("flight","qa_flight").filter(F.col("qa_flight") == "F").show()
# Out:
# +---------+-----+
# |qa_flight|count|
# +---------+-----+
# |        F| 6158|
# |     null| 3842|
# +---------+-----+
#
# +------+---------+
# |flight|qa_flight|
# +------+---------+
# |   851|        F|
# |   755|        F|
# |   344|        F|
# |   522|        F|
# |    48|        F|
# |   755|        F|
# |   490|        F|
# |    26|        F|
# |   448|        F|
# |   656|        F|
# |   608|        F|
# |   121|        F|
# |   306|        F|
# |   368|        F|
# |   827|        F|
# |    24|        F|
# |   300|        F|
# |   616|        F|
# |   306|        F|
# |    29|        F|
# +------+---------+
# only showing top 20 rows

# %% [markdown]
# ### Pergunta 8

# %%
df_flights = df_flights.withColumn('qa_origin_dest',
                  F.when(F.col('origin').isNull(), "MO")
                  .when(F.col('dest').isNull(), "MD")
                  .when(~F.col('origin').rlike("^[a-zA-Z0-9_]{3}$"), "FO")
                  .when(~F.col('dest').rlike("^[a-zA-Z0-9_]{3}$"), "FD")
                  )



df_flights.groupBy("qa_origin_dest").count().distinct().show()
# Out:
# +--------------+-----+
# |qa_origin_dest|count|
# +--------------+-----+
# |          null|10000|
# +--------------+-----+

# %% [markdown]
# ### Pergunta 9

# %%
df_flights = df_flights.withColumn("qa_air_time",
                  F.when(F.col('air_time').isNull(), "M")
                  .when(~F.col('air_time').between(20,500), "I")
                  )


df_flights.groupBy("qa_air_time").count().distinct().show()
df_flights.filter(F.col('qa_air_time')=="M").toPandas()
# Out:
# +-----------+-----+
# |qa_air_time|count|
# +-----------+-----+
# |       null| 9925|
# |          M|   75|
# +-----------+-----+
#     year  month  day dep_time  dep_delay arr_time  arr_delay carrier tailnum  \
# 0   2014      4    6     1329        4.0     2159        NaN      DL  N130DL
# 1   2014      3    4       NA        NaN       NA        NaN      UA      NA
# 2   2014      2   12       NA        NaN       NA        NaN      AS  N527AS
# 3   2014      7    1       NA        NaN       NA        NaN      WN  N8323C
# 4   2014     12   27     1420       40.0     2012        NaN      OO  N224AG
# ..   ...    ...  ...      ...        ...      ...        ...     ...     ...
# 70  2014      2   11      840        0.0     1646        NaN      HA  N389HA
# 71  2014      4   16     2224       -6.0       46        NaN      OO  N234SW
# 72  2014     10   14       NA        NaN       NA        NaN      AS  N529AS
# 73  2014      2   17       NA        NaN       NA        NaN      WN  N449WN
# 74  2014      8   12       NA        NaN       NA        NaN      OO  N162PQ
#
#    flight  ... minute qa_year_month_day  qa_hour_minute  qa_dep_arr  \
# 0    1929  ...   29.0              None            None        None
# 1     156  ...    NaN              None              MH          MD
# 2       2  ...    NaN              None              MH          MD
# 3    2485  ...    NaN              None              MH          MD
# 4    3452  ...   20.0              None            None        None
# ..    ...  ...    ...               ...             ...         ...
# 70     21  ...   40.0              None            None        None
# 71   5437  ...   24.0              None            None          FA
# 72    413  ...    NaN              None              MH          MD
# 73   1900  ...    NaN              None              MH          MD
# 74   4489  ...    NaN              None              MH          MD
#
#     qa_dep_arr_delay  qa_carrier qa_tailnum qa_flight qa_origin_dest  \
# 0                 MA        None       None      None           None
# 1                 MD        None          M         F           None
# 2                 MD        None       None         F           None
# 3                 MD        None       None      None           None
# 4                 MA        None       None      None           None
# ..               ...         ...        ...       ...            ...
# 70                MA        None       None         F           None
# 71                MA        None       None      None           None
# 72                MD        None       None         F           None
# 73                MD        None       None      None           None
# 74                MD        None       None      None           None
#
#    qa_air_time
# 0            M
# 1            M
# 2            M
# 3            M
# 4            M
# ..         ...
# 70           M
# 71           M
# 72           M
# 73           M
# 74           M
#
# [75 rows x 25 columns]

# %% [markdown]
# ### Pergunta 10

# %%
df_flights = df_flights.withColumn("qa_distance",
                  F.when(F.col('distance').isNull(), "M")
                  .when(~F.col('distance').between(50,3000), "I")
                  )


df_flights.groupBy("qa_distance").count().distinct().show()
# Out:
# +-----------+-----+
# |qa_distance|count|
# +-----------+-----+
# |       null|10000|
# +-----------+-----+

# %% [markdown]
# ### Pergunta 11

# %%
df_flights = df_flights.withColumn('qa_distance_airtime', (
        F.when((check_empty_column('distance')) | (check_empty_column('air_time')), 'M')
         .when((F.col('air_time') >= F.col('distance') * 0.1 + 30), 'TL')
         .when((F.col('air_time') <= F.col('distance') * 0.1 + 10), 'TS')
         .otherwise('TR')))




df_flights.groupBy("qa_distance_airtime").count().distinct().show()
df_flights.show(1)
# Out:
# +-------------------+-----+
# |qa_distance_airtime|count|
# +-------------------+-----+
# |                  M|   75|
# |                 TR| 4831|
# |                 TS|   67|
# |                 TL| 5027|
# +-------------------+-----+
#
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-----------------+--------------+----------+----------------+----------+----------+---------+--------------+-----------+-----------+-------------------+
# |year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|qa_year_month_day|qa_hour_minute|qa_dep_arr|qa_dep_arr_delay|qa_carrier|qa_tailnum|qa_flight|qa_origin_dest|qa_air_time|qa_distance|qa_distance_airtime|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-----------------+--------------+----------+----------------+----------+----------+---------+--------------+-----------+-----------+-------------------+
# |2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|             null|          null|      null|            null|      null|      null|     null|          null|       null|       null|                 TL|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+-----------------+--------------+----------+----------------+----------+----------+---------+--------------+-----------+-----------+-------------------+
# only showing top 1 row

# %% [markdown]
# ### Criando Flights parquet

# %%
flightsparq = (df_flights.select("tailnum","dest","origin","qa_tailnum",'qa_year_month_day','qa_hour_minute','qa_dep_arr','qa_dep_arr_delay','qa_carrier','qa_flight','qa_origin_dest','qa_air_time','qa_distance','qa_distance_airtime')
            .repartition(1) # coalesce
            .write.format("parquet")
            .mode('overwrite')
            .option("header", "true")
            .save('flights_qa.parquet'))
